# %% [markdown]
# ## 02_basic_stats_countries

# %%
## 02_basic_stats_countries.py
# Basic statistics for countries dataset

from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# データ読み込み
# プロジェクトルートを明示的に固定
PROJECT_ROOT = Path(r"E:\Analytics\My-Statistics-for-Data-Analysis")
DATA_PATH = PROJECT_ROOT / "data" / "02_countries_basic_stats.csv"
df = pd.read_csv(DATA_PATH)


# データの確認
print(df.head())
print(df.info())
print(df.describe())
# Out:
#      country    region  population_million  gdp_per_capita_usd  \
# 0  Country_A  Region_1                 5.0               32000
# 1  Country_B  Region_1                18.0               28000
# 2  Country_C  Region_1                42.0               35000
# 3  Country_D  Region_1                 9.0               26000
# 4  Country_E  Region_2                65.0               12000
#
#    life_expectancy  average_age
# 0               82           44
# 1               80           42
# 2               83           45
# 3               79           41
# 4               74           36
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             16 non-null     str
#  1   region              16 non-null     str
#  2   population_million  16 non-null     float64
#  3   gdp_per_capita_usd  16 non-null     int64
#  4   life_expectancy     16 non-null     int64
#  5   average_age         16 non-null     int64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 900.0 bytes
# None
#        population_million  gdp_per_capita_usd  life_expectancy  average_age
# count           16.000000           16.000000        16.000000    16.000000
# mean            52.343750        27293.750000        77.437500    39.625000
# std             59.519386        21324.960922         6.142407     5.783597
# min              1.500000         5000.000000        68.000000    31.000000
# 25%              8.500000         8800.000000        71.750000    34.750000
# 50%             30.000000        22000.000000        78.000000    39.500000
# 75%             72.500000        38250.000000        83.000000    45.000000
# max            210.000000        70000.000000        86.000000    48.000000

# %%
# 基本統計量の計算
# 平均（mean）
mean_values = df.mean(numeric_only=True)
# 中央値（median）
median_values = df.median(numeric_only=True)
# 四分位数（quartiles）
quartiles = df.quantile([0.25, 0.5, 0.75], numeric_only=True)

# ばらつきの指標
# 分散（variance）
variance_values = df.var(numeric_only=True, ddof=1)  # 標本分散
# 標準偏差（standard deviation）
std_values = df.std(numeric_only=True, ddof=1)  # 標本標準偏差
# 最小値（min）
min_values = df.min(numeric_only=True)
# 最大値（max）
max_values = df.max(numeric_only=True)

# 結果の表示
print("Mean:\n", mean_values)
print("\nMedian:\n", median_values)
print("\nQuartiles:\n", quartiles)
print("\nVariance:\n", variance_values)
print("\nStandard Deviation:\n", std_values)
print("\nMin:\n", min_values)
print("\nMax:\n", max_values)
# Out:
# Mean:
#  population_million       52.34375
# gdp_per_capita_usd    27293.75000
# life_expectancy          77.43750
# average_age              39.62500
# dtype: float64
#
# Median:
#  population_million       30.0
# gdp_per_capita_usd    22000.0
# life_expectancy          78.0
# average_age              39.5
# dtype: float64
#
# Quartiles:
#        population_million  gdp_per_capita_usd  life_expectancy  average_age
# 0.25                 8.5              8800.0            71.75        34.75
# 0.50                30.0             22000.0            78.00        39.50
# 0.75                72.5             38250.0            83.00        45.00
#
# Variance:
#  population_million    3.542557e+03
# gdp_per_capita_usd    4.547540e+08
# life_expectancy       3.772917e+01
# average_age           3.345000e+01
# dtype: float64
#
# Standard Deviation:
#  population_million       59.519386
# gdp_per_capita_usd    21324.960922
# life_expectancy           6.142407
# average_age               5.783597
# dtype: float64
#
# Min:
#  population_million       1.5
# gdp_per_capita_usd    5000.0
# life_expectancy         68.0
# average_age             31.0
# dtype: float64
#
# Max:
#  population_million      210.0
# gdp_per_capita_usd    70000.0
# life_expectancy          86.0
# average_age              48.0
# dtype: float64

# %%
# 可視化
# ヒストグラムの作成
df["population_million"].hist(bins=10, edgecolor="black")
plt.title("Population Distribution")
plt.xlabel("Population (million)")
plt.ylabel("Frequency")
plt.show()

# %%
# 箱ひげ図の作成
df.boxplot(column="gdp_per_capita_usd")
plt.title("GDP Distribution")
plt.ylabel("GDP (per capita, USD)")
plt.show()
